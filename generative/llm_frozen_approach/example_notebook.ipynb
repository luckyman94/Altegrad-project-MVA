# %% [markdown]
# # Train Encoder + Mapper (using llm which are decoder only such as GPT2 or BIOGPT)

# %% [markdown]
# Train encoder + mapper

# %% [markdown]
# !python /content/Altegrad-project-MVA/generative/llm_frozen_approach/training/train_encoder_mapper.py \
#   --train_graphs /content/drive/MyDrive/molecule-captioning/data/train_graphs.pkl  \
#   --checkpoint_path /content/checkpoints \
#   --epochs 10 \
#   --batch_size 64 \
#   --lr 5e-5 \
#   --llm biogpt

# %% [markdown]
# Inference

# %% [markdown]
# !python /content/Altegrad-project-MVA/generative/llm_frozen_approach/inference/inference.py \
# --test_graphs /content/drive/MyDrive/molecule-captioning/data/test_graphs.pkl  \
# --checkpoint_path /content/checkpoints/best_graph2text.pt \
# --batch_size 64 \
# --llm biogpt
