# %% [markdown]
# !python /kaggle/working/Altegrad-project-MVA/retrieval/generate_description_embeddings.py \
# --model bert-base-uncased \
# --data_dir /kaggle/input/molecular-graph-captioning/data_baseline/data \
# --out_dir /kaggle/working/embeddings/
